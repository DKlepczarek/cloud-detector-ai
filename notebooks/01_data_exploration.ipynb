# %%
# Służy do sprawdzenia, czy zdjęcia się ładują i jak wyglądają
import matplotlib.pyplot as plt
import os

# %%
# Zliczanie zdjęć w folderach
data_dir = '../data/raw'
for folder in os.listdir(data_dir):
    print(f"Class {folder}: {len(os.listdir(os.path.join(data_dir, folder)))} images")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 # Zliczanie zdjęć w folderach
#       2 data_dir = '../data/raw'
# ----> 3 for folder in os.listdir(data_dir):
#       4     print(f"Class {folder}: {len(os.listdir(os.path.join(data_dir, folder)))} images")
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/raw'
